# %% [markdown]
# <a href="https://colab.research.google.com/github/YuxuanJiao/17-CleanedData/blob/main/GCSE_Cleaned_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas

gcse_raw=pandas.read_excel('gcse-results-old.xls')

gcse_raw
# Out:
#    Unnamed: 0                Unnamed: 1  \
# 0        Code                      Area
# 1         NaN                       NaN
# 2   E09000001            City of London
# 3   E09000002      Barking and Dagenham
# 4   E09000003                    Barnet
# 5   E09000004                    Bexley
# 6   E09000005                     Brent
# 7   E09000006                   Bromley
# 8   E09000007                    Camden
# 9   E09000008                   Croydon
# 10  E09000009                    Ealing
# 11  E09000010                   Enfield
# 12  E09000011                 Greenwich
# 13  E09000012                   Hackney
# 14  E09000013    Hammersmith and Fulham
# 15  E09000014                  Haringey
# 16  E09000015                    Harrow
# 17  E09000016                  Havering
# 18  E09000017                Hillingdon
# 19  E09000018                  Hounslow
# 20  E09000019                 Islington
# 21  E09000020    Kensington and Chelsea
# ...

# %%
gcse_cleaned = gcse_raw.iloc[:, [1,3,4,5,6,7] ]

gcse_cleaned
# Out:
#                   Unnamed: 1 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0                       Area    2010/11    2011/12    2012/13    2013/14
# 1                        NaN        NaN        NaN        NaN        NaN
# 2             City of London          .          .          .          .
# 3       Barking and Dagenham       57.2       58.6       60.2       58.2
# 4                     Barnet       68.8       69.2       71.5       67.5
# 5                     Bexley       63.3       64.9         66       60.3
# 6                      Brent       62.1       58.7       62.9         60
# 7                    Bromley       67.2       68.9       73.9       65.6
# 8                     Camden       60.2         59       60.4       60.5
# 9                    Croydon         61       62.2       64.4       56.8
# 10                    Ealing       57.3       57.7       60.9       59.8
# 11                   Enfield       59.5       55.5       63.2       59.7
# ...
