# %% [markdown]
# <a href="https://colab.research.google.com/github/YuxuanJiao/17-CleanedData/blob/main/3sportsrate_Cleaned.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas

sports_raw = pandas.read_excel('sports-participation-borough-region.xls')

sports_raw
# Out:
#    Age 16+ Sports participation - At least three times a week\n  \
# 0                                                Code
# 1                                           E12000001
# 2                                           E12000002
# 3                                           E12000003
# 4                                           E12000004
# 5                                           E12000005
# 6                                           E12000006
# 7                                           E12000007
# 8                                           E12000008
# 9                                           E12000009
# 10                                          E92000001
# 11                                                NaN
# 12                                          E09000001
# 13                                          E09000002
# 14                                          E09000003
# 15                                          E09000004
# ...

# %%
sports_cleaned = sports_raw.iloc[:,[2,11,13,15,17,19]]

columns=sports_cleaned.columns[1:]
for i in columns:
          sports_cleaned[i] = pandas.to_numeric(sports_cleaned[i], errors='coerce')
sports_cleaned
# Out:
# <ipython-input-9-297b3c13a488>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sports_cleaned[i] = pandas.to_numeric(sports_cleaned[i], errors='coerce')
#                 Unnamed: 2  APS5 2010/11  APS6 2011/12  APS7 2012/13  \
# 0                Area name           NaN           NaN           NaN
# 1               North East         0.166         0.185         0.185
# 2               North West         0.176         0.183         0.183
# 3                Yorkshire         0.177         0.180         0.182
# 4            East Midlands         0.158         0.173         0.163
# 5            West Midlands         0.153         0.161         0.165
# 6                     East         0.163         0.169         0.169
# ...
